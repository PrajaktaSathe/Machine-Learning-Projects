# %%
import numpy as np
import pandas as pd # Import required libraries

# %%
heart_data = pd.read_csv('Heart.csv') # Load data

# %%
heart_data.head() # First 5 values
# Out:
#    Unnamed: 0   Age  Sex     ChestPain  RestBP   Chol  Fbs  RestECG  MaxHR  \
# 0           1  63.0    1       typical   145.0  233.0  1.0      2.0  150.0
# 1           2  67.0    1  asymptomatic   160.0  286.0  0.0      2.0  108.0
# 2           3  67.0    1  asymptomatic   120.0  229.0  0.0      2.0  129.0
# 3           4  37.0    1    nonanginal   130.0  250.0  0.0      0.0  187.0
# 4           5  41.0    0    nontypical   130.0  204.0  0.0      2.0  172.0
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0    0.0      2.3    3.0  0.0       fixed   No
# 1    1.0      1.5    2.0  3.0      normal  Yes
# 2    1.0      2.6    2.0  2.0  reversable  Yes
# 3    0.0      3.5    3.0  0.0      normal   No
# 4    0.0      1.4    1.0  0.0      normal   No

# %%
heart_data.tail() # Last 5 values
# Out:
#      Unnamed: 0   Age  Sex     ChestPain  RestBP   Chol  Fbs  RestECG  MaxHR  \
# 298         299  45.0    1       typical   110.0    NaN  0.0      NaN  132.0
# 299         300  68.0    1  asymptomatic   144.0  193.0  1.0      0.0    NaN
# 300         301  57.0    1  asymptomatic   130.0  131.0  0.0      0.0  115.0
# 301         302  57.0    0    nontypical   130.0  236.0  0.0      2.0  174.0
# 302         303  38.0    1    nonanginal     NaN  175.0  0.0      0.0  173.0
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 298    0.0      1.2    2.0  0.0  reversable  Yes
# 299    0.0      3.4    2.0  2.0  reversable  Yes
# 300    1.0      1.2    2.0  1.0  reversable  Yes
# 301    0.0      0.0    2.0  1.0      normal  Yes
# 302    0.0      0.0    1.0  NaN      normal   No

# %%
heart_data.shape # Dimensions of the data
# Out:
# (303, 15)

# %%
heart_data.info
# Out:
# <bound method DataFrame.info of      Unnamed: 0   Age  Sex     ChestPain  RestBP   Chol  Fbs  RestECG  MaxHR  \
# 0             1  63.0    1       typical   145.0  233.0  1.0      2.0  150.0
# 1             2  67.0    1  asymptomatic   160.0  286.0  0.0      2.0  108.0
# 2             3  67.0    1  asymptomatic   120.0  229.0  0.0      2.0  129.0
# 3             4  37.0    1    nonanginal   130.0  250.0  0.0      0.0  187.0
# 4             5  41.0    0    nontypical   130.0  204.0  0.0      2.0  172.0
# ..          ...   ...  ...           ...     ...    ...  ...      ...    ...
# 298         299  45.0    1       typical   110.0    NaN  0.0      NaN  132.0
# 299         300  68.0    1  asymptomatic   144.0  193.0  1.0      0.0    NaN
# 300         301  57.0    1  asymptomatic   130.0  131.0  0.0      0.0  115.0
# 301         302  57.0    0    nontypical   130.0  236.0  0.0      2.0  174.0
# 302         303  38.0    1    nonanginal     NaN  175.0  0.0      0.0  173.0
#
# ...

# %%
heart_data.describe # In-depth description of dataframe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0   Age  Sex     ChestPain  RestBP   Chol  Fbs  RestECG  MaxHR  \
# 0             1  63.0    1       typical   145.0  233.0  1.0      2.0  150.0
# 1             2  67.0    1  asymptomatic   160.0  286.0  0.0      2.0  108.0
# 2             3  67.0    1  asymptomatic   120.0  229.0  0.0      2.0  129.0
# 3             4  37.0    1    nonanginal   130.0  250.0  0.0      0.0  187.0
# 4             5  41.0    0    nontypical   130.0  204.0  0.0      2.0  172.0
# ..          ...   ...  ...           ...     ...    ...  ...      ...    ...
# 298         299  45.0    1       typical   110.0    NaN  0.0      NaN  132.0
# 299         300  68.0    1  asymptomatic   144.0  193.0  1.0      0.0    NaN
# 300         301  57.0    1  asymptomatic   130.0  131.0  0.0      0.0  115.0
# 301         302  57.0    0    nontypical   130.0  236.0  0.0      2.0  174.0
# 302         303  38.0    1    nonanginal     NaN  175.0  0.0      0.0  173.0
#
# ...

# %%
heart_data.dtypes # Datatypes of each column in dataset
# Out:
# Unnamed: 0      int64
# Age           float64
# Sex             int64
# ChestPain      object
# RestBP        float64
# Chol          float64
# Fbs           float64
# RestECG       float64
# MaxHR         float64
# ExAng         float64
# Oldpeak       float64
# Slope         float64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
heart_data.isna() # Shows if value is  null
# Out:
#      Unnamed: 0    Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  \
# 0         False  False  False      False   False  False  False    False
# 1         False  False  False      False   False  False  False    False
# 2         False  False  False      False   False  False  False    False
# 3         False  False  False      False   False  False  False    False
# 4         False  False  False      False   False  False  False    False
# ..          ...    ...    ...        ...     ...    ...    ...      ...
# 298       False  False  False      False   False   True  False     True
# 299       False  False  False      False   False  False  False    False
# 300       False  False  False      False   False  False  False    False
# 301       False  False  False      False   False  False  False    False
# 302       False  False  False      False    True  False  False    False
#
#      MaxHR  ExAng  Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
heart_data.fillna(heart_data.mean()) # Fill null values with mean of dataset
# Out:
#      Unnamed: 0   Age  Sex     ChestPain      RestBP        Chol  Fbs  \
# 0             1  63.0    1       typical  145.000000  233.000000  1.0
# 1             2  67.0    1  asymptomatic  160.000000  286.000000  0.0
# 2             3  67.0    1  asymptomatic  120.000000  229.000000  0.0
# 3             4  37.0    1    nonanginal  130.000000  250.000000  0.0
# 4             5  41.0    0    nontypical  130.000000  204.000000  0.0
# ..          ...   ...  ...           ...         ...         ...  ...
# 298         299  45.0    1       typical  110.000000  246.504983  0.0
# 299         300  68.0    1  asymptomatic  144.000000  193.000000  1.0
# 300         301  57.0    1  asymptomatic  130.000000  131.000000  0.0
# 301         302  57.0    0    nontypical  130.000000  236.000000  0.0
# 302         303  38.0    1    nonanginal  131.571906  175.000000  0.0
#
#       RestECG       MaxHR  ExAng  Oldpeak  Slope        Ca        Thal  AHD
# ...

# %%
heart_data.mean(axis=1)
# Out:
# 0      50.108333
# 1      52.791667
# 2      46.550000
# 3      51.291667
# 4      46.366667
#          ...
# 298    59.020000
# 299    64.945455
# 300    61.683333
# 301    75.333333
# 302    69.100000
# Length: 303, dtype: float64

# %%
heart_data["Age"].mean() # Mean of age of patient
# Out:
# 54.47682119205298

# %%
# Create new dataframe taking the required columns - 
heart_data_sel = pd.DataFrame(heart_data, columns=['Age','Sex','ChestPain','RestBP','Chol'])
heart_data_sel
# Out:
#       Age  Sex     ChestPain  RestBP   Chol
# 0    63.0    1       typical   145.0  233.0
# 1    67.0    1  asymptomatic   160.0  286.0
# 2    67.0    1  asymptomatic   120.0  229.0
# 3    37.0    1    nonanginal   130.0  250.0
# 4    41.0    0    nontypical   130.0  204.0
# ..    ...  ...           ...     ...    ...
# 298  45.0    1       typical   110.0    NaN
# 299  68.0    1  asymptomatic   144.0  193.0
# 300  57.0    1  asymptomatic   130.0  131.0
# 301  57.0    0    nontypical   130.0  236.0
# 302  38.0    1    nonanginal     NaN  175.0
#
# [303 rows x 5 columns]

# %%
# Split dataset into training and testing sets (Taking training dataset size as 80%)
from sklearn.model_selection import train_test_split
x_train, x_test = train_test_split(heart_data_sel, train_size=0.8)
print(x_train.shape, x_test.shape)
# Out:
# (242, 5) (61, 5)

# %%
# Age vs. Chest Pain
from matplotlib import pyplot as plt
plt.scatter(heart_data_sel['Age'],heart_data_sel['ChestPain'])
plt.title('Age vs. Chest Pain')
plt.xlabel('Age')
plt.ylabel('Chest Pain')
# Out:
# Text(0, 0.5, 'Chest Pain')

# %%
# Age vs. Rest BP
plt.scatter(heart_data_sel['Age'],heart_data_sel['RestBP'])
plt.title('Age vs. Rest BP')
plt.xlabel('Age')
plt.ylabel('Rest BP')
# Out:
# Text(0, 0.5, 'Rest BP')

# %%
# Age vs. Cholestrol
plt.scatter(heart_data_sel['Age'],heart_data_sel['Chol'])
plt.title('Age vs. Chol')
plt.xlabel('Age')
plt.ylabel('Cholestrol')
# Out:
# Text(0, 0.5, 'Cholestrol')
